# %%
# %matplotlib inline
import numpy as np
import io
import pandas as pd
from stop_words import get_stop_words
from nltk.tokenize import RegexpTokenizer
from gensim import corpora, models
import gensim
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image
import PIL.ImageOps
import random
from wordcloud import ImageColorGenerator
import os
import string
import re

# %%
os.chdir('/Users/JamesWang1/Dropbox/BassConnectionsRAs/HS Survey/wordcloudScript')

# %%
df = pd.read_excel("wordCloudTokens Noah Edits.xlsx")

# %%
df.columns
# Out:
# Index(['Tokens', 'Score'], dtype='object')

# %%
#mask1 = np.array(Image.open('WCMasksIdeas/election-2018.jpg'))
mask1 = np.array(Image.open("/Users/JamesWang1/Dropbox/BassConnectionsRAs/HS Survey/aVisuals For posters/123.png"))
image_colors = ImageColorGenerator(mask1)

# %%
wc1 = WordCloud(background_color="white", mask = mask1, random_state = 6)
wc = wc1.fit_words(dict(zip(df.Tokens, df.Score)))

# %%
plt.figure(figsize = (20,20))
plt.imshow(wc.recolor(color_func= image_colors))
plt.axis("off")
os.chdir('/Users/JamesWang1/Dropbox/BassConnectionsRAs/HS Survey//aVisuals For posters')
wc.to_file("2018WC4.png")
pass

# %%
os.chdir('/Users/JamesWang1/Dropbox/BassConnectionsRAs/HS Survey/wordcloudScript/WCMasksIdeas')

# %%
fname = "/Users/JamesWang1/Downloads/samadult.dat"

# %%
dt = np.dtype('float32')
import numpy as np
x = np.fromfile(fname, dtype=dt)

# %%
x.shape
# Out:
# (9390800,)

# %%
np.loadtxt( fname )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-1fbaa77813e7> in <module>()
# ----> 1 np.loadtxt( fname )
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#    1019                 line_num = i + skiprows + 1
#    1020                 raise ValueError("Wrong number of columns at line %d"
# -> 1021                                  % line_num)
#    1022
#    1023             # Convert each value according to its column and store
#
# ValueError: Wrong number of columns at line 2
